# %%
#UNDERSTANDING YOUR DATA ( ASKING BASICS QUESTION FROM DATA)

# %%
import pandas as pd

# %%
df = pd.read_csv('train.csv')

# %%
#1- how big is the data ?
df.shape
# Out:
# (891, 12)

# %%
#2- how does the data look like ?
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#how does the data look like?
# if you dont want to avoid biasness so use random samples random rows biase means if staring 10 row  are in range of 10 you think thats its a data of children but its not the case so use sample random rows
df.sample(5)
# Out:
#      PassengerId  Survived  Pclass  \
# 478          479         0       3
# 106          107         1       3
# 418          419         0       2
# 40            41         0       3
# 494          495         0       3
#
#                                                Name     Sex   Age  SibSp  \
# 478                       Karlsson, Mr. Nils August    male  22.0      0
# 106                Salkjelsvik, Miss. Anna Kristine  female  21.0      0
# 418                      Matthews, Mr. William John    male  30.0      0
# 40   Ahlin, Mrs. Johan (Johanna Persdotter Larsson)  female  40.0      1
# 494                      Stanley, Mr. Edward Roland    male  21.0      0
#
#      Parch     Ticket     Fare Cabin Embarked
# 478      0     350060   7.5208   NaN        S
# 106      0     343120   7.6500   NaN        S
# 418      0      28228  13.0000   NaN        S
# 40       0       7546   9.4750   NaN        S
# 494      0  A/4 45380   8.0500   NaN        S

# %%
#3-what is data type of col
df.info()   # get info about dta like as age value is in float in this data but we coud use integer as well so by take care of these thing wwe can save the memory
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
#4-are there any missing values?
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
#5-how does data look mathematically?
df.describe()    # it told us if i saw age coloumn so the mean age of pasenger is 29 25% people age is less than or equals to 20nand if i check fare so mean fare is 0 and max fare is 512
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
#6-is there any duplicate values?
df.duplicated().sum()  # no duplcte row or col in any other dataset the are chances of duplication which could remove by drop dulicated function
# Out:
# np.int64(0)

# %%
#7-how is the correlation between cols?  colrelation is if 1 incease so what would be the effect on other if no effect so remov ethat fazzol coloumn no use of that coloumn
df.corr(numeric_only=True)
#-ive sign showws taht there is less relation invesly proportional in negative means no less dependency and -ive means high dependency and directly propertional ek k barhny sai dosra bhi barhyga
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
df.corr(numeric_only=True)['Survived']   # chcek there isno reltion inversly rpopetional of survived and passengerid and directly relation of survied with fare 0.257 as fare in ameer hongy so survival invc log zada koshish krengy bachany ki
# Out:
# PassengerId   -0.005007
# Survived       1.000000
# Pclass        -0.338481
# Age           -0.077221
# SibSp         -0.035322
# Parch          0.081629
# Fare           0.257307
# Name: Survived, dtype: float64
