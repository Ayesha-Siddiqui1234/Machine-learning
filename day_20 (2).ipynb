# %%
#EDA USING UNIVARIATE ANALYSIS
#univariate analysis is in which we analyis 1 coloumn
#in bivariate analysis we do analysis of 2 coloumn
# if more than 1 so its multivariate
#data are of 2 types 1- numerical e.g price , height ,age 2- categorical data is state, nationality , gender

# %%
import pandas as pd
import seaborn as sns

# %%
df= pd.read_csv('train.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
                         #{  CATEGORICAL DATA  }
#A-COUNT PLOT:  YOU COULD DO THIS COUNT PLOT ON ANY COLOUMN  (CHECKING FREQUENCY COUNT FROM EACH COLOUMN)
#sns.countplot(df['Survived'])
df['Survived'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Survived'>

# %%
df['Pclass'].value_counts().plot(kind='bar')   # in 3rd class majority in 2 class minority
# Out:
# <Axes: xlabel='Pclass'>

# %%
df['Sex'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Sex'>

# %%
df['Embarked'].value_counts().plot(kind='bar')   # majorty people are from S and minority are from Q
# Out:
# <Axes: xlabel='Embarked'>

# %%
#PIE CHART (IF WE WANT THE FREQUENCY OF EACH COLOUMN K KITNY NUM OF LOGON KI WO SPECIFIC CHIZ KITNI HAI IN PERCENTAGE SO MAKE PIE CHART)
#df['Survived'].value_counts().plot(kind='pie', autopct= '%.2f')  # its shows that more died(0) less survive (1)
#df['Sex'].value_counts().plot(kind='pie', autopct= '%.2f')
#df['Pclass'].value_counts().plot(kind='pie', autopct= '%.2f')

# %%
                         #{  NUMERICAL DATA  }
# A-HISTOGRAM (TO SEE THE DISTRIBUTION OF DATA IN NUMERICAL COLOUMN)
import matplotlib.pyplot as plt
plt.hist(df['Age'],bins=5)   # if we incease the bins to much like 50 so choty choty levels pai markers create hojaty hn like from 0 to 10 age 1 ,2 ,3, ,5 .....  so hoty levels pai points create hogy or if bhot km krden like 5 so bhot door door markers create hojaty hn
# Out:
# (array([100., 346., 188.,  69.,  11.]),
#  array([ 0.42 , 16.336, 32.252, 48.168, 64.084, 80.   ]),
#  <BarContainer object of 5 artists>)

# %%
#DISPLOT
sns.distplot(df['Fare'])  #less people have higher fare its would we positively skewd
#sns.distplot(df['Age'])   # its a pdf probability density function if we want to check the propebability f age will b 40 is so we can calculate its will be  in the middle of0.015 and 0.010 #df['Age'].skew()  # (shows less people have high age its right skewed positive skewed)
# Out:
# /tmp/ipython-input-3833853374.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Fare'])
# <Axes: xlabel='Fare', ylabel='Density'>

# %%
#BOX PLOT
#Q3(75 PERCENTILE) THATS MEANS 75% LOG AP SAI PECHY HN
#Q1 (25 PERCENTILE)
#IQR (INTER QURTILE RANGE Q3-Q1)
#MAXIMUN = Q3 +1.5*IQR
#MINIMUM = Q1 -1.5*IQR
#THE POINTS LESSURE THAN OR GREATER THAN MAX AND MINIMUM ARE THE OUTLIERS

# %%
#sns.boxplot(df['Fare']) # kesi ka fare is 500 its way more thna the fare of others so its a outlier out of the context fare from others fare
sns.boxplot(df['Age']) # the otliers are the age of 65 70 and 80
# Out:
# <Axes: ylabel='Age'>

# %%
# we can caluclate the max and min of each e.g age
#df['Age'].min()
#df['Age'].max()
#['Fare'].max()
#df['Fare'].min()
#df['Age'].skew()  # (shows less people have high age its right skewed positive skewed)
#df['Fare'].skew()  #positive skewed more less people have higher fare
# Out:
# np.float64(4.787316519674893)

# %%
# PRACTICE OF UNIVARIENT ANALYSIS ON STUDENT_PERFORMANCE DATASET

# %%
df = pd.read_csv('Student_Performance.csv')
df.head()
# Out:
#    student_id  age  gender school_type parent_education  study_hours  \
# 0           1   14    male      public    post graduate          3.1
# 1           2   18  female      public         graduate          3.7
# 2           3   17  female     private    post graduate          7.9
# 3           4   16   other      public      high school          1.1
# 4           5   16  female      public      high school          1.3
#
#    attendance_percentage internet_access travel_time extra_activities  \
# 0                   84.3             yes     <15 min              yes
# 1                   87.8             yes     >60 min               no
# 2                   65.5              no     <15 min               no
# 3                   58.1              no   15-30 min               no
# 4                   61.0             yes   30-60 min              yes
#
#   study_method  math_score  science_score  english_score  overall_score  \
# ...

# %%
#COUNT_PLOT
#df['internet_access'].value_counts().plot(kind='bar')
#df['parent_education'].value_counts().plot(kind='bar')
#df['study_method'].value_counts().plot(kind='bar')
#df['school_type'].value_counts().plot(kind='bar')
df['gender'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='gender'>

# %%
# PIE CHART
#df['study_method'].value_counts().plot(kind='pie', autopct='%.2f')
#df['internet_access'].value_counts().plot(kind='pie', autopct='%.2f')
df['parent_education'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
#NUMERICAL DATA
#HISTOGRAM
import matplotlib.pyplot as plt
#plt.hist(df['math_score'])
plt.hist(df['travel_time'])
# Out:
# (array([6127.,    0.,    0., 6166.,    0.,    0., 6362.,    0.,    0.,
#         6345.]),
#  array([0. , 0.3, 0.6, 0.9, 1.2, 1.5, 1.8, 2.1, 2.4, 2.7, 3. ]),
#  <BarContainer object of 10 artists>)

# %%
#DISTPLOT
#sns.distplot(df['attendance_percentage'])
sns.distplot(df['science_score'])
# Out:
# /tmp/ipython-input-367251277.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['science_score'])
# <Axes: xlabel='science_score', ylabel='Density'>

# %%
df['science_score'].skew()
# Out:
# np.float64(-0.13529798986156394)
