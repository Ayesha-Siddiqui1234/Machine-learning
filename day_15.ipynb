# %%
import pandas as pd

# %%
#want to getdat from any csv file
df=pd.read_csv('/content/CSV.csv')

# %%
df
# Out:
#                     Country Name Country Code      1961      1962      1963  \
# 0                          Aruba          ABW  2.179059  1.548572  1.389337
# 1    Africa Eastern and Southern          AFE  2.660180  2.732633  2.753248
# 2                    Afghanistan          AFG  1.925952  2.014879  2.078997
# 3     Africa Western and Central          AFW  2.115789  2.145723  2.190827
# 4                         Angola          AGO  1.558355  1.460738  1.410425
# ..                           ...          ...       ...       ...       ...
# 261                       Kosovo          XKX  2.400980  2.378001  2.336873
# 262                  Yemen, Rep.          YEM  1.862737  1.872291  1.839467
# 263                 South Africa          ZAF  2.799492  2.978651  3.033440
# 264                       Zambia          ZMB  3.156056  3.178563  3.196632
# 265                     Zimbabwe          ZWE  3.094865  3.105320  3.115408
#
# ...

# %%
#if you want to load by using link
import pandas as pd

# CSV file link
url = "https://people.sc.fsu.edu/~jburkardt/data/csv/airtravel.csv"

# Read CSV data directly from the URL
data = pd.read_csv(url)

# Display first few rows
print(data.head())
# Out:
#   Month   "1958"   "1959"   "1960"
# 0   JAN      340      360      417
# 1   FEB      318      342      391
# 2   MAR      362      406      419
# 3   APR      348      396      461
# 4   MAY      363      420      472

# %%
pd.read_csv('/content/student_data.tsv',sep='\t')
#\t for run the tsv file
# Out:
#      Name  Age Grade        City
# 0  Ayesha   20     A     Karachi
# 1  Kashaf   21     B      Lahore
# 2  Areeba   19     A   Islamabad
# 3   Ahmed   22     C  Faisalabad

# %%
#coloumn names when are not defined
pd.read_csv('/content/noColoumn.csv', sep=',', names=['Names','Age','Grade','City'])
# Out:
#     Names  Age Grade        City
# 0   Alina   34     C      Quetta
# 1  Ayesha   20     A     Karachi
# 2  Kashaf   21     B      Lahore
# 3  Areeba   19     A   Islamabad
# 4   Ahmed   22     C  Faisalabad

# %%
#to get just specific coloumns
pd.read_csv('/content/CSV.csv', usecols=['Country Name','Country Code','1967','2011','2023'])
# Out:
#                     Country Name Country Code      1967      2011      2023
# 0                          Aruba          ABW  0.388847  0.939356 -0.157953
# 1    Africa Eastern and Southern          AFE  2.830505  2.738185  2.531587
# 2                    Afghanistan          AFG  2.292638  3.689508  2.665628
# 3     Africa Western and Central          AFW  2.275721  2.848826  2.540864
# 4                         Angola          AGO  0.696698  3.758796  3.030996
# ..                           ...          ...       ...       ...       ...
# 261                       Kosovo          XKX  2.099215  0.377238 -0.664615
# 262                  Yemen, Rep.          YEM  2.216335  2.914067  2.210656
# 263                 South Africa          ZAF  3.089296  1.263406  0.865465
# 264                       Zambia          ZMB  3.219669  3.377110  2.720528
# 265                     Zimbabwe          ZWE  3.135761  1.438339  2.091100
#
# [266 rows x 5 columns]

# %%
#skip the rows
pd.read_csv('/content/noColoumn.csv',skiprows=[1,2])
# Out:
#     Alina  34  C      Quetta
# 0  Areeba  19  A   Islamabad
# 1   Ahmed  22  C  Faisalabad

# %%
#according to our own get no of rows
pd.read_csv('/content/CSV.csv',nrows=36)
# Out:
#                    Country Name Country Code      1961      1962      1963  \
# 0                         Aruba          ABW  2.179059  1.548572  1.389337
# 1   Africa Eastern and Southern          AFE  2.660180  2.732633  2.753248
# 2                   Afghanistan          AFG  1.925952  2.014879  2.078997
# 3    Africa Western and Central          AFW  2.115789  2.145723  2.190827
# 4                        Angola          AGO  1.558355  1.460738  1.410425
# 5                       Albania          ALB  3.120855  3.056731  2.953749
# 6                       Andorra          AND  7.868139  7.521207  7.223198
# 7                    Arab World          ARB  2.571718  2.619388  2.670051
# 8          United Arab Emirates          ARE  5.509939  5.447405  5.316356
# 9                     Argentina          ARG  1.613029  1.629282  1.621661
# 10                      Armenia          ARM  3.477523  3.381928  3.222867
# ...

# %%
# it will handle the special correct as well without showing error it convert the character into utf-8 for encoding
pd.read_csv('/content/special_characters.csv',encoding='latin-1')
# Out:
#        Name  Country  Age
# 0      José    Spain   28
# 1  François   France   35
# 2   München  Germany   30
# 3    Garçon   France   22
# 4  Señorita   Mexico   25

# %%
pd.read_csv('/content/skip.csv')
# Out:
#      Name   Age       City
# 0  Ayesha   NaN        NaN
# 1  Kashaf  21.0     Lahore
# 2  Areeba   NaN        NaN
# 3    Zara  22.0  Islamabad
# 4     Ali   NaN        NaN
# 5   Ahmed   NaN     Multan

# %%
#for skipping  bad lines
pd.read_csv('/content/skip.csv', sep=',', encoding="latin-1", on_bad_lines='skip')
# Out:
#      Name   Age       City
# 0  Ayesha   NaN        NaN
# 1  Kashaf  21.0     Lahore
# 2  Areeba   NaN        NaN
# 3    Zara  22.0  Islamabad
# 4     Ali   NaN        NaN
# 5   Ahmed   NaN     Multan

# %%
#pd.read_csv('/content/date.csv').info()   # treat as object
pd.read_csv('/content/date.csv',parse_dates=['date']).info()   # now treat as date
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    6 non-null      object
#  1   Age     6 non-null      int64
#  2   City    6 non-null      object
#  3   date    6 non-null      datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(2)
# memory usage: 324.0+ bytes

# %%
#for renaming any field
def rename(name):
  if name == "Ayesha":
    return "jeeni"
  else:
    return name

# %%
rename("Ayesha")
# Out:
# 'jeeni'

# %%
pd.read_csv("/content/date.csv",converters={'Name' :rename})
# Out:
#      Name  Age       City        date
# 0   jeeni   87    karachi  2008-02-04
# 1  Kashaf   21     Lahore   2009-6-12
# 2  Areeba   23     lahore   2010-8-23
# 3    Zara   22  Islamabad  2018-09-07
# 4     Ali    5  hyderabad   2004-7-24
# 5   Ahmed    6     Multan   2025-8-12

# %%
a = pd.read_csv('/content/CSV.csv',chunksize=100)

# %%
for chunks in a:
  print(chunks.shape)
